# %%
import matplotlib.pyplot as plt
import streamlit as st
import numpy as np
import pandas  as pd
import seaborn as sns
# df=pd.read_csv("path of the csv file")
# x = df['Sales']
# y = df['Units']
# plt.plot(x, y)
# st.pyplot(plt)




st.title("Matplotlib Graphs")

x = np.linspace(0, 10, 100)
y = np.sin(x)

# 1. Line
fig, ax = plt.subplots()
ax.plot(x, y)
st.pyplot(fig)

# 2. Bar
fig, ax = plt.subplots()
ax.bar(["A", "B", "C"], [10, 20, 15])
st.pyplot(fig)

# 3. Histogram
data = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(data, bins=30)
st.pyplot(fig)

# 4. Scatter
fig, ax = plt.subplots()
ax.scatter(x, y)
st.pyplot(fig)

# 5. Pie Chart
fig, ax = plt.subplots()
ax.pie([30, 40, 30], labels=["A", "B", "C"], autopct="%1.1f%%")
st.pyplot(fig)

# 6. Boxplot
fig, ax = plt.subplots()
ax.boxplot(np.random.randn(100))
st.pyplot(fig)

# 7. Area Chart
fig, ax = plt.subplots()
ax.fill_between(x, y)
st.pyplot(fig)

# 8. Stem Plot
fig, ax = plt.subplots()
ax.stem(x[:10], y[:10])
st.pyplot(fig)

# 9. Step Plot
fig, ax = plt.subplots()
ax.step(x, y)
st.pyplot(fig)

# 10. Error Bars
fig, ax = plt.subplots()
ax.errorbar(x, y, yerr=0.1)
st.pyplot(fig)

# 11. Heatmap (Matplotlib)
fig, ax = plt.subplots()
c = ax.imshow(np.random.rand(10, 10))
fig.colorbar(c)
st.pyplot(fig)

# 12. Polar Plot
fig = plt.figure()
ax = fig.add_subplot(111, polar=True)
ax.plot(x, np.abs(np.sin(x)))
st.pyplot(fig)

# 13. Subplots
fig, axs = plt.subplots(1, 2)
axs[0].plot(x, np.cos(x))
axs[1].plot(x, np.sin(x))
st.pyplot(fig)

# 14. Logarithmic Plot
fig, ax = plt.subplots()
ax.semilogy(x, np.exp(x/3))
st.pyplot(fig)

# 15. Barh (horizontal bar)
fig, ax = plt.subplots()
ax.barh(["X", "Y", "Z"], [5, 10, 3])
st.pyplot(fig)
# Out:
# 2025-06-25 11:57:32.913 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:33.635
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\royal\AppData\Roaming\Python\Python313\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-06-25 11:57:33.636 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:33.637 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:33.778 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:34.098 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:34.100 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:34.102 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:34.126 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:34.270 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:34.271 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:34.274 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:34.330 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:34.482 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:34.484 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:34.486 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:34.502 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:34.671 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:34.672 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:34.673 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:34.704 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:34.775 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:34.777 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:34.778 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:34.808 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:34.901 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:34.903 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:34.904 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:34.917 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:35.202 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:35.204 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:35.204 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:35.222 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:35.413 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:35.415 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:35.416 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:35.429 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:35.571 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:35.573 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:35.574 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:35.588 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:35.722 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:35.723 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:35.726 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:35.761 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:35.967 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:35.969 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:35.970 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:35.997 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:36.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:36.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:36.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:36.181 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:36.469 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:36.470 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:36.470 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:36.486 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:36.997 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:36.999 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:37.002 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:37.036 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:37.180 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:37.182 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-25 11:57:37.184 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
