# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randint(0,200,20),columns=['sales'])

# %%
df.head()
# Out:
#    sales
# 0    180
# 1     25
# 2    165
# 3    165
# 4     57

# %%
df
# Out:
#     sales
# 0     180
# 1      25
# 2     165
# 3     165
# 4      57
# 5     132
# 6     167
# 7      72
# 8     189
# 9       8
# 10     93
# 11     86
# 12     50
# 13    115
# 14     36
# 15    198
# 16     40
# 17    164
# 18     98
# 19    140

# %%
import matplotlib.pyplot as plt

# %%
pip install matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 4.1 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.1/8.1 MB 5.8 MB/s eta 0:00:02
#    -------------------- ------------------- 4.2/8.1 MB 7.5 MB/s eta 0:00:01
#    --------------------------------- ------ 6.8/8.1 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 9.7 MB/s eta 0:00:00
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 12.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 2.7/2.7 MB 19.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
plt.figure(figsize=(20,5))

# %%
plt.xlabel("Index")
# Out:
# Text(0.5, 0, 'Index')

# %%
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %%
plt.title("Sales vs Index")
# Out:
# Text(0.5, 1.0, 'Sales vs Index')

# %%
plt.plot(df['sales'],marker='o',color='#000000',markerfacecolor='w',markeredgecolor='green',markeredgewidth=2,linewidth=0,alpha=0.9)

# %%
plt.figure(figsize=(10,7))
plt.plot(df['sales'],marker='o',color='#000000',markerfacecolor='w',markeredgecolor='green',markeredgewidth=1,linewidth=2,alpha=0.9)
plt.xlabel("Index")
plt.ylabel("Sales")
plt.title("Sales vs Index")
# Out:
# Text(0.5, 1.0, 'Sales vs Index')

# %%
df=pd.DataFrame(np.random.randint(0,10,(10,5)),columns="A B C D E".split())
df
# Out:
#    A  B  C  D  E
# 0  1  5  8  6  8
# 1  3  7  6  5  3
# 2  2  6  4  2  4
# 3  4  1  3  5  5
# 4  9  4  2  9  5
# 5  1  3  0  0  8
# 6  2  3  2  4  6
# 7  7  2  5  3  9
# 8  9  1  3  1  8
# 9  7  9  0  8  5

# %%
plt.subplot(2,2,1)
plt.plot(df['A'],color='r')
plt.subplot(2,2,2)
plt.plot(df['B'],color='b')
plt.subplot(2,2,3)
plt.plot(df['C'],color='y')
plt.subplot(2,2,4)
plt.plot(df['D'])

# %%
plt.subplot(2,3,1)
plt.plot(df['A'],color='r')
plt.subplot(2,3,2)
plt.plot(df['B'],color='b')
plt.subplot(2,3,3)
plt.plot(df['C'],color='y')
plt.subplot(2,3,4)
plt.plot(df['D'])
