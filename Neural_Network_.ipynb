# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD

# %%
data=np.array([[0,0],[0,1],[1,0],[1,1]])

# %%
X=data
y=np.array([[0], [0], [0], [1]])

# %%
model=Sequential()
model.add(Dense(1,input_dim=2,activation='sigmoid'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Train the model
model.fit(X, y, epochs=100, verbose=1)

# Evaluate the model
loss, accuracy = model.evaluate(X, y)
print(f"\nAccuracy: {accuracy*100:.2f}%")

# Make predictions
print("\nPredictions:")
print(model.predict(X))
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0150
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.0147
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0145
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.0143
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0141
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 0.0139
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0136
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0135
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0133
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0131
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0129
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.0127
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.0126
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0124
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0122
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0121
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0119
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0118
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0116
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.0115
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.0114
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0112
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 0.0111
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0110
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 0.0109
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0107
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 1.0000 - loss: 0.0106
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 1.0000 - loss: 0.0105
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0104
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0103
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.0102
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 1.0000 - loss: 0.0101
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 0.0100
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.0098
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 1.0000 - loss: 0.0097
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 1.0000 - loss: 0.0097
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.0096
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0095
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0094
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 1.0000 - loss: 0.0093
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 0.0092
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 1.0000 - loss: 0.0091
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0090
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0089
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0089
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0088
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0087
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0086
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0085
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0085
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0084
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0083
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0082
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0082
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0081
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0080
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0080
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0079
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0078
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0078
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0077
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0077
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0076
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.0075
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.0075
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0074
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0074
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0073
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0072
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0072
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0071
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0071
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0070
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0070
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0069
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0069
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0068
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0068
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0067
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 0.0067
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.0066
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0066
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0065
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0065
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0065
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0064
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0064
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0063
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0063
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0062
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0062
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0062
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0061
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0061
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0060
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0060
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.0060
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0059
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0059
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0059
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0058
#
# Accuracy: 100.00%
#
# Predictions:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# [[0.9910173 ]
#  [0.9932239 ]
#  [0.99752575]
#  [0.9974547 ]
#  [0.01105112]
#  [0.99701005]]

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD

X = np.array([[0, 0],
              [0, 1],
              [1, 0],
              [1, 1]])

y = np.array([[0], [0], [0], [1]])

model = Sequential()
model.add(Dense(5, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer=SGD(learning_rate=0.1), loss='binary_crossentropy', metrics=['accuracy'])

model.fit(X, y, epochs=100, verbose=1)

loss, accuracy = model.evaluate(X, y)
print(f"\nAccuracy: {accuracy * 100:.2f}%")
print("\nPredictions:")
print(model.predict(X))
# Out:
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 693ms/step - accuracy: 0.5000 - loss: 0.7023
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5000 - loss: 0.6932
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5000 - loss: 0.6847
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5000 - loss: 0.6767
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5000 - loss: 0.6691
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7500 - loss: 0.6620
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7500 - loss: 0.6552
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.7500 - loss: 0.6489
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.6428
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.6371
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.6317
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.6266
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.6217
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7500 - loss: 0.6170
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7500 - loss: 0.6125
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7500 - loss: 0.6083
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7500 - loss: 0.6042
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7500 - loss: 0.6003
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7500 - loss: 0.5965
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7500 - loss: 0.5929
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7500 - loss: 0.5894
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7500 - loss: 0.5861
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7500 - loss: 0.5828
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7500 - loss: 0.5797
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.7500 - loss: 0.5767
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7500 - loss: 0.5738
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7500 - loss: 0.5709
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7500 - loss: 0.5682
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7500 - loss: 0.5655
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7500 - loss: 0.5629
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7500 - loss: 0.5603
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7500 - loss: 0.5578
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7500 - loss: 0.5554
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7500 - loss: 0.5530
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7500 - loss: 0.5507
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7500 - loss: 0.5484
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7500 - loss: 0.5461
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7500 - loss: 0.5439
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7500 - loss: 0.5417
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7500 - loss: 0.5396
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7500 - loss: 0.5375
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7500 - loss: 0.5354
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7500 - loss: 0.5333
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7500 - loss: 0.5313
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7500 - loss: 0.5293
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7500 - loss: 0.5273
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7500 - loss: 0.5253
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7500 - loss: 0.5233
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7500 - loss: 0.5213
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7500 - loss: 0.5194
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7500 - loss: 0.5175
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7500 - loss: 0.5155
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7500 - loss: 0.5136
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7500 - loss: 0.5117
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7500 - loss: 0.5098
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7500 - loss: 0.5079
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7500 - loss: 0.5061
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7500 - loss: 0.5042
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.7500 - loss: 0.5023
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7500 - loss: 0.5005
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7500 - loss: 0.4986
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7500 - loss: 0.4968
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7500 - loss: 0.4949
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7500 - loss: 0.4930
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7500 - loss: 0.4912
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7500 - loss: 0.4893
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7500 - loss: 0.4875
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7500 - loss: 0.4856
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7500 - loss: 0.4838
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7500 - loss: 0.4819
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7500 - loss: 0.4801
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.7500 - loss: 0.4782
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7500 - loss: 0.4764
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.7500 - loss: 0.4745
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7500 - loss: 0.4726
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7500 - loss: 0.4708
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.7500 - loss: 0.4689
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.7500 - loss: 0.4671
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.7500 - loss: 0.4652
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.7500 - loss: 0.4633
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.7500 - loss: 0.4614
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.7500 - loss: 0.4596
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.7500 - loss: 0.4577
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.7500 - loss: 0.4558
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.7500 - loss: 0.4539
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7500 - loss: 0.4521
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.7500 - loss: 0.4502
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.7500 - loss: 0.4483
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.7500 - loss: 0.4464
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7500 - loss: 0.4445
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7500 - loss: 0.4427
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7500 - loss: 0.4408
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7500 - loss: 0.4389
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7500 - loss: 0.4370
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7500 - loss: 0.4351
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7500 - loss: 0.4332
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7500 - loss: 0.4313
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7500 - loss: 0.4295
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7500 - loss: 0.4276
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7500 - loss: 0.4257
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.7500 - loss: 0.4238
#
# Accuracy: 75.00%
#
# Predictions:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# [[0.20913792]
#  [0.33219075]
#  [0.30385286]
#  [0.49925935]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD

X = np.random.randint(0,10,(5,35))

y = np.random.randint(0,2,(5,1))

model = Sequential()
model.add(Dense(5, input_dim=35, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer=SGD(learning_rate=0.1),
              loss='binary_crossentropy',
              metrics=['accuracy'])

history = model.fit(X, y, epochs=100, verbose=0)

loss, accuracy = model.evaluate(X, y, verbose=0)
print(f"\nFinal Accuracy: {accuracy * 100:.2f}%")

print("\nPredictions:")
print(model.predict(X))

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], color='red', label='Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], color='blue', label='Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Final Accuracy: 100.00%
#
# Predictions:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# [[4.7502696e-04]
#  [1.1996896e-03]
#  [1.3166641e-04]
#  [1.1628123e-03]
#  [6.6607761e-01]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD

X = np.random.randint(0,10,(20,35))

y = np.random.randint(0,2,(20,1))

model = Sequential()
model.add(Dense(5, input_dim=35, activation='linear'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer=SGD(learning_rate=0.1),
              loss='binary_crossentropy',
              metrics=['accuracy'])

history = model.fit(X, y, epochs=100, verbose=0)

loss, accuracy = model.evaluate(X, y, verbose=0)
print(f"\nFinal Accuracy: {accuracy * 100:.2f}%")

print("\nPredictions:")
print(model.predict(X))

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], color='red', label='Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], color='blue', label='Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Final Accuracy: 100.00%
#
# Predictions:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# [[9.9966580e-01]
#  [9.9373043e-01]
#  [9.9981892e-01]
#  [8.1967637e-03]
#  [1.5972683e-02]
#  [9.9509501e-01]
#  [1.3233935e-03]
#  [4.2100367e-03]
#  [9.8641843e-01]
#  [9.2875706e-03]
#  [8.1731108e-05]
#  [9.9715024e-01]
#  [9.9322510e-01]
#  [5.4236264e-03]
#  [6.2548031e-07]
#  [6.2702680e-03]
#  [2.2519404e-02]
#  [9.8995692e-01]
#  [9.9462688e-01]
#  [9.7839755e-01]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD

X = np.random.randint(0,10,(200,6))

y = np.random.randint(0,2,(200,1))

model = Sequential()
model.add(Dense(5, input_dim=6, activation='tanh'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer=SGD(learning_rate=0.1),
              loss='binary_crossentropy',
              metrics=['accuracy'])

history = model.fit(X, y, epochs=100, verbose=0)

loss, accuracy = model.evaluate(X, y, verbose=0)
print(f"\nFinal Accuracy: {accuracy * 100:.2f}%")

print("\nPredictions:")
print(model.predict(X))

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], color='red', label='Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], color='blue', label='Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Final Accuracy: 62.00%
#
# Predictions:
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# WARNING:tensorflow:5 out of the last 10 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7bdc87c20360> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# [[0.58536136]
#  [0.4987241 ]
#  [0.3175078 ]
#  [0.28961882]
#  [0.53506666]
#  [0.5828467 ]
#  [0.40907493]
#  [0.46829084]
#  [0.58489263]
#  [0.4406874 ]
#  [0.5822105 ]
#  [0.2922954 ]
#  [0.5851164 ]
#  [0.32217553]
#  [0.5736151 ]
#  [0.47050214]
#  [0.16920772]
#  [0.3435119 ]
#  [0.4454149 ]
#  [0.42341903]
#  [0.53149015]
#  [0.5254572 ]
#  [0.49186027]
#  [0.4433327 ]
#  [0.28906864]
#  [0.29230654]
#  [0.26646042]
#  [0.44079337]
#  [0.5855723 ]
#  [0.5833157 ]
#  [0.4090843 ]
#  [0.34652218]
#  [0.48885438]
#  [0.4812441 ]
#  [0.44132254]
#  [0.39919132]
#  [0.44314477]
#  [0.2829908 ]
#  [0.20325251]
#  [0.44304544]
#  [0.5850061 ]
#  [0.5848371 ]
#  [0.54720026]
#  [0.47631422]
#  [0.5722243 ]
#  [0.45198324]
#  [0.5484145 ]
#  [0.3522416 ]
#  [0.509003  ]
#  [0.58514696]
#  [0.33484536]
#  [0.30594033]
#  [0.26084015]
#  [0.57620096]
#  [0.52361315]
#  [0.5286087 ]
#  [0.33978474]
#  [0.43664983]
#  [0.28367254]
#  [0.5846941 ]
#  [0.37271056]
#  [0.44448566]
#  [0.31989685]
#  [0.47184575]
#  [0.21336333]
#  [0.4232183 ]
#  [0.4880958 ]
#  [0.55890685]
#  [0.5852038 ]
#  [0.52770394]
#  [0.20534022]
#  [0.4928177 ]
#  [0.46366653]
#  [0.4417838 ]
#  [0.30749238]
#  [0.5487323 ]
#  [0.5506024 ]
#  [0.57218015]
#  [0.44349927]
#  [0.44121873]
#  [0.44143707]
#  [0.5778685 ]
#  [0.5605866 ]
#  [0.58526707]
#  [0.53444767]
#  [0.299577  ]
#  [0.58408767]
#  [0.5849004 ]
#  [0.36006498]
#  [0.5287953 ]
#  [0.55121714]
#  [0.31979212]
#  [0.4699518 ]
#  [0.31291908]
#  [0.45789024]
#  [0.31949067]
#  [0.5789097 ]
#  [0.4549145 ]
#  [0.4680449 ]
#  [0.29088876]
#  [0.42495355]
#  [0.45729163]
#  [0.58353305]
#  [0.58527005]
#  [0.44669712]
#  [0.5721615 ]
#  [0.36009094]
#  [0.308173  ]
#  [0.31543598]
#  [0.50250447]
#  [0.46516624]
#  [0.44230917]
#  [0.57244074]
#  [0.2178235 ]
#  [0.44094527]
#  [0.5667778 ]
#  [0.49794292]
#  [0.3205746 ]
#  [0.4982673 ]
#  [0.21903113]
#  [0.23357162]
#  [0.5818366 ]
#  [0.5809654 ]
#  [0.3841199 ]
#  [0.49013546]
#  [0.57083714]
#  [0.3643564 ]
#  [0.40372375]
#  [0.57536   ]
#  [0.54293   ]
#  [0.5819112 ]
#  [0.5714567 ]
#  [0.3975978 ]
#  [0.48755231]
#  [0.4251744 ]
#  [0.5383941 ]
#  [0.4915312 ]
#  [0.21161014]
#  [0.22431783]
#  [0.52443486]
#  [0.5810916 ]
#  [0.58354455]
#  [0.341549  ]
#  [0.2765714 ]
#  [0.29498374]
#  [0.3248456 ]
#  [0.41096067]
#  [0.4304221 ]
#  [0.5572813 ]
#  [0.4462173 ]
#  [0.5040327 ]
#  [0.2635469 ]
#  [0.3070411 ]
#  [0.58541894]
#  [0.2993691 ]
#  [0.30064794]
#  [0.22155747]
#  [0.32113066]
#  [0.4252522 ]
#  [0.42297488]
#  [0.5391587 ]
#  [0.2190165 ]
#  [0.43742847]
#  [0.46183833]
#  [0.46435034]
#  [0.5171725 ]
#  [0.37298444]
#  [0.5852633 ]
#  [0.4282483 ]
#  [0.5854688 ]
#  [0.58489937]
#  [0.5550727 ]
#  [0.44577506]
#  [0.5772489 ]
#  [0.44530225]
#  [0.57969   ]
#  [0.50166786]
#  [0.47337314]
#  [0.49846876]
#  [0.4598088 ]
#  [0.32798925]
#  [0.5850473 ]
#  [0.4450541 ]
#  [0.56197315]
#  [0.4419061 ]
#  [0.45423877]
#  [0.49794954]
#  [0.3810105 ]
#  [0.3163385 ]
#  [0.4477288 ]
#  [0.224806  ]
#  [0.31738624]
#  [0.4593022 ]
#  [0.57855994]
#  [0.20811991]
#  [0.2509903 ]
#  [0.5747195 ]
#  [0.36529005]
#  [0.4861175 ]
#  [0.51462036]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD

X = np.random.randint(0,10,(17,6))

y = np.random.randint(0,2,(17,1))

model = Sequential()
model.add(Dense(5, input_dim=6, activation='softmax'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer=SGD(learning_rate=0.1),
              loss='binary_crossentropy',
              metrics=['accuracy'])

history = model.fit(X, y, epochs=100, verbose=0)

loss, accuracy = model.evaluate(X, y, verbose=0)
print(f"\nFinal Accuracy: {accuracy * 100:.2f}%")

print("\nPredictions:")
print(model.predict(X))

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], color='red', label='Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], color='blue', label='Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7bdc8f3bede0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Final Accuracy: 64.71%
#
# Predictions:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# [[0.51540947]
#  [0.53082937]
#  [0.76243216]
#  [0.75445795]
#  [0.747248  ]
#  [0.751186  ]
#  [0.7259261 ]
#  [0.7683179 ]
#  [0.6092604 ]
#  [0.5151882 ]
#  [0.66833436]
#  [0.7648277 ]
#  [0.7218848 ]
#  [0.52735925]
#  [0.6366027 ]
#  [0.5174621 ]
#  [0.5373654 ]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD

X = np.random.randint(0,10,(16,21))

y = np.random.randint(0,2,(16,1))

model = Sequential()
model.add(Dense(5, input_dim=21, activation='exponential'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer=SGD(learning_rate=0.1),
              loss='binary_crossentropy',
              metrics=['accuracy'])

history = model.fit(X, y, epochs=100, verbose=0)

loss, accuracy = model.evaluate(X, y, verbose=0)
print(f"\nFinal Accuracy: {accuracy * 100:.2f}%")

print("\nPredictions:")
print(model.predict(X))

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], color='red', label='Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], color='blue', label='Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Final Accuracy: 50.00%
#
# Predictions:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# [[0.5003909 ]
#  [0.50038755]
#  [0.5003612 ]
#  [0.5003977 ]
#  [0.50033563]
#  [0.5000239 ]
#  [0.500595  ]
#  [0.50017047]
#  [0.5003964 ]
#  [0.5001137 ]
#  [0.5003977 ]
#  [0.50038934]
#  [0.50035733]
#  [0.5002555 ]
#  [0.5003842 ]
#  [0.5003959 ]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD

X = np.random.randint(0,10,(6,5))

y = np.random.randint(0,2,(6,1))

model = Sequential()
model.add(Dense(5, input_dim=5, activation='swish'))
model.add(Dense(1, activation='linear'))

model.compile(optimizer=SGD(learning_rate=0.1),
              loss='binary_crossentropy',
              metrics=['accuracy'])

history = model.fit(X, y, epochs=100, verbose=0)

loss, accuracy = model.evaluate(X, y, verbose=0)
print(f"\nFinal Accuracy: {accuracy * 100:.2f}%")

print("\nPredictions:")
print(model.predict(X))

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], color='red', label='Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], color='blue', label='Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Final Accuracy: 50.00%
#
# Predictions:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# [[-0.3180406 ]
#  [-3.333292  ]
#  [ 1.1700115 ]
#  [ 2.9222722 ]
#  [-0.45016295]
#  [ 2.2339177 ]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD

X = np.random.randint(0,10,(10,5))

y = np.random.randint(0,2,(10,1))

model = Sequential()
model.add(Dense(5, input_dim=5, activation='linear'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer=SGD(learning_rate=0.1),
              loss='binary_crossentropy',
              metrics=['accuracy'])

history = model.fit(X, y, epochs=100, verbose=0)

loss, accuracy = model.evaluate(X, y, verbose=0)
print(f"\nFinal Accuracy: {accuracy * 100:.2f}%")

print("\nPredictions:")
print(model.predict(X))

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], color='red', label='Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], color='blue', label='Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Final Accuracy: 80.00%
#
# Predictions:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# [[0.9746712 ]
#  [0.00128629]
#  [0.9630954 ]
#  [0.2856267 ]
#  [0.48785815]
#  [0.31086963]
#  [0.9992505 ]
#  [0.03242801]
#  [0.43385324]
#  [0.9755126 ]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD

X = np.random.randint(0,10,(6,5))

y = np.random.randint(0,2,(6,1))

model = Sequential()
model.add(Dense(5, input_dim=5, activation='softplus'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer=SGD(learning_rate=0.1),
              loss='binary_crossentropy',
              metrics=['accuracy'])

history = model.fit(X, y, epochs=100, verbose=0)

loss, accuracy = model.evaluate(X, y, verbose=0)
print(f"\nFinal Accuracy: {accuracy * 100:.2f}%")

print("\nPredictions:")
print(model.predict(X))

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], color='red', label='Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], color='blue', label='Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Final Accuracy: 100.00%
#
# Predictions:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# [[0.9862687 ]
#  [0.9996505 ]
#  [0.00680676]
#  [0.01052087]
#  [0.9998426 ]
#  [0.01023464]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD

X = np.random.randint(0,10,(6,5))

y = np.random.randint(0,2,(6,1))

model = Sequential()
model.add(Dense(5, input_dim=5, activation='softsign'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer=SGD(learning_rate=0.1),
              loss='binary_crossentropy',
              metrics=['accuracy'])

history = model.fit(X, y, epochs=100, verbose=0)

loss, accuracy = model.evaluate(X, y, verbose=0)
print(f"\nFinal Accuracy: {accuracy * 100:.2f}%")

print("\nPredictions:")
print(model.predict(X))

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], color='red', label='Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], color='blue', label='Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Final Accuracy: 100.00%
#
# Predictions:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# [[0.73800683]
#  [0.06995516]
#  [0.09048706]
#  [0.05515725]
#  [0.78584033]
#  [0.2657911 ]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD

X = np.random.randint(0,10,(6,5))

y = np.random.randint(0,2,(6,1))

model = Sequential()
model.add(Dense(5, input_dim=5, activation='elu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer=SGD(learning_rate=0.1),
              loss='binary_crossentropy',
              metrics=['accuracy'])

history = model.fit(X, y, epochs=100, verbose=0)

loss, accuracy = model.evaluate(X, y, verbose=0)
print(f"\nFinal Accuracy: {accuracy * 100:.2f}%")

print("\nPredictions:")
print(model.predict(X))

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], color='red', label='Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], color='blue', label='Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Final Accuracy: 100.00%
#
# Predictions:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# [[0.99988407]
#  [0.00175248]
#  [0.98046684]
#  [0.07358037]
#  [0.99999887]
#  [0.9268246 ]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD

X = np.random.randint(0,10,(6,5))

y = np.random.randint(0,2,(6,1))

model = Sequential()
model.add(Dense(5, input_dim=5, activation='selu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer=SGD(learning_rate=0.1),
              loss='binary_crossentropy',
              metrics=['accuracy'])

history = model.fit(X, y, epochs=100, verbose=0)

loss, accuracy = model.evaluate(X, y, verbose=0)
print(f"\nFinal Accuracy: {accuracy * 100:.2f}%")

print("\nPredictions:")
print(model.predict(X))

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], color='red', label='Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], color='blue', label='Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Final Accuracy: 100.00%
#
# Predictions:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# [[0.9770283 ]
#  [0.9872789 ]
#  [0.9950702 ]
#  [0.99493736]
#  [0.03682673]
#  [0.99387133]]

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from keras import backend as K

# Define 20 activation functions and their formulas
activation_functions = {
    "linear": lambda x: x,
    "sigmoid": tf.keras.activations.sigmoid,
    "tanh": tf.keras.activations.tanh,
    "relu": tf.keras.activations.relu,
    "softplus": tf.keras.activations.softplus,
    "softsign": tf.keras.activations.softsign,
    "selu": tf.keras.activations.selu,
    "elu": tf.keras.activations.elu,
    "exponential": tf.keras.activations.exponential,
    "hard_sigmoid": tf.keras.activations.hard_sigmoid,
    "swish": lambda x: x * tf.keras.activations.sigmoid(x),
    "mish": lambda x: x * tf.math.tanh(tf.math.softplus(x)),
    "leaky_relu": lambda x: tf.nn.leaky_relu(x, alpha=0.2),
    "prelu": lambda x: tf.maximum(0.1 * x, x),
    "gelu": tf.keras.activations.gelu,
    "bent_identity": lambda x: ((np.sqrt(x ** 2 + 1) - 1) / 2) + x,
    "arctangent": lambda x: tf.math.atan(x),
    "sinc": lambda x: tf.where(x == 0, tf.ones_like(x), tf.math.sin(x) / x),
    "gaussian": lambda x: tf.exp(-tf.square(x)),
    "sign": lambda x: tf.sign(x),
}

# Input range for plotting
x_vals = np.linspace(-10, 10, 500)
x_tensor = tf.convert_to_tensor(x_vals, dtype=tf.float32)

# Plotting
plt.figure(figsize=(20, 20))
for i, (name, func) in enumerate(activation_functions.items()):
    plt.subplot(5, 4, i+1)
    y_vals = func(x_tensor)
    plt.plot(x_vals, y_vals.numpy())
    plt.title(name)
    plt.grid(True)

plt.tight_layout()
plt.suptitle("Activation Functions", fontsize=20, y=1.02)
plt.show()

# %%
# Compile the model
model.compile(optimizer=SGD(), loss='binary_crossentropy', metrics=['accuracy'])
